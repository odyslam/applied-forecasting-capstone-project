# %% [markdown]
# # Forecasting initial notebook
#
# The idea is here that I am writing

# %%
import pandas as pd 
col_names = ["date", "device_id", "org_id"]
data = pd.read_csv("analytics_devices_online.csv", names = col_names, header=None) \

# %%
from datetime import datetime
import matplotlib.pyplot as plt

format = '%Y-%m-%d'
# data['date'] is the column with all the dates
data['date'] = pd.to_datetime(data['date'])
df = data.groupby('date').count()
del df['org_id']
df = df.rename(columns={'device_id': 'device_count'})
df.head()
# Out:
#             device_count
# date
# 2015-07-14            53
# 2015-07-15            53
# 2015-07-16            56
# 2015-07-17            57
# 2015-07-18            57

# %%
from datetime import datetime
import matplotlib.pyplot as plt

format = '%Y-%m-%d'
# data['date'] is the column with all the dates
data['date'] = pd.to_datetime(data['date'])
gb = data.groupby('org_id')    
orgs = [gb.get_group(x) for x in gb.groups]

# %%
ml_orgs = data.groupby(['date', 'org_id']).count().reset_index()
ml_orgs = ml_orgs.rename(columns={'device_id': 'device_count'})
ml_orgs.tail()


# print(ml_orgs)

# f = plt.figure(figsize=(19, 15))
# cor = ml_orgs[['date', 'org_id', 'device_count']].corr()
# print(cor)
# plt.matshow(cor, fignum=f.number)
# plt.xticks(range(ml_orgs.shape[1]), ml_orgs.columns, fontsize=14, rotation=45)
# plt.yticks(range(ml_orgs.shape[1]), ml_orgs.columns, fontsize=14)
# cb = plt.colorbar()
# cb.ax.tick_params(labelsize=14)
# plt.title('Correlation Matrix', fontsize=16);
# Out:
#              date  org_id  device_count
# 663698 2019-03-31   52579             1
# 663699 2019-03-31   52580             1
# 663700 2019-03-31   52584             1
# 663701 2019-03-31   52585             1
# 663702 2019-03-31   52590             3

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics

plt.figure(figsize=(16,16))

X_test = np.asarray(ml_orgs['org_id']).reshape(-1,1)
y_test = np.asarray(ml_orgs['device_count']).reshape(-1,1)

regressor = LinearRegression()
regressor.fit(X_test, y_test) #training the algorithm
y_pred = regressor.predict(np.asarray(ml_orgs['org_id']).reshape(-1,1))


plt.scatter(X_test, y_test,  color='gray')
plt.plot(X_test, y_pred, color='red', linewidth=2)
plt.ylabel("Device count")
plt.xlabel("Organization ID")

plt.show()

# %%
print("Length of orgs:", len(orgs))

for org in orgs:
    count_org= org.groupby(['date', 'org_id'], sort = True).count().reset_index()
    count_org = count_org.rename(columns={'device_id': 'device_count'})
    plt.plot(count_org['date'], count_org['device_count'])
    

plt.show()    
print(count_org)
print(orgs[45])
print(orgs[0], orgs[-1])
# Out:
# Length of orgs: 11921
#         date  org_id  device_count
# 0 2019-03-31   52590             3
#               date  device_id  org_id
# 241690  2017-05-16     580758      61
# 274824  2017-06-15     580758      61
# 342293  2017-05-15     580758      61
# 346080  2017-05-23     580758      61
# 353070  2017-05-18     580758      61
# ...            ...        ...     ...
# 6546473 2019-03-31    1457280      61
# 6547132 2019-03-31    1078786      61
# 6547467 2019-03-31    1577379      61
# 6547791 2019-03-31     946507      61
# 6548122 2019-03-31    1574983      61
#
# [7580 rows x 3 columns]
#               date  device_id  org_id
# 44604   2016-06-02     185718       7
# 53958   2016-07-18     185718       7
# 60661   2016-05-31     185718       7
# 61038   2016-07-14     185718       7
# 61456   2016-08-03     202488       7
# ...            ...        ...     ...
# 6548398 2019-03-31     994574       7
# 6548726 2019-03-31    1313057       7
# 6548727 2019-03-31    1175541       7
# 6548728 2019-03-31    1043246       7
# 6548729 2019-03-31    1441998       7
#
# [77361 rows x 3 columns]               date  device_id  org_id
# 6531702 2019-03-31    1579180   52590
# 6534695 2019-03-31    1579178   52590
# 6535351 2019-03-31    1579181   52590

# %%
width = 10
height = 10
plt.rcParams['figure.figsize'] = [width, height]
plt.plot(df)

# %%
# Monthly sum
df_msum = df.groupby(pd.Grouper(freq='M')).sum()
df_mmean = df.groupby(pd.Grouper(freq='M')).mean()
df_wmean = df.groupby(pd.Grouper(freq='W')).mean()
plt.title("Monthly mean number of online devices")
plt.plot(df_mmean)

# %%
plt.title("Monthly number of online devices")
# plt.plot(df_msum)
plt.plot(df_wmean)

# %% [markdown]
#  1. TODO1 each row is a specific device which was online for that date, thus I have to find the number of devices that were online each day and at the same time map them to different fleets (by org_id)
#  2. TODO2 observe the fleet size and start decomposition, removal of outliers, de-seasonalization
#  3. Research from the available material and decide on the methods to use for the forecasting, theta fore sure in terms of the statistical one
#  4. cut the data sets into test set and validation set
#  5.

# %%
import numpy as np

df_array = np.array(df_mmean['device_count'])
grad = np.gradient(df_array)
second_grad = np.gradient(grad)

plt.ylabel('first gradient of monthly sums')
months = df_msum.index.month_name()
# plt.xticks(df_msum.index.date, rotation = 'vertical')
plt.plot(df_msum.index.date, grad)
plt.plot(df_msum.index.date, second_grad)
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-f8111de0c666> in <module>
#       1 import numpy as np
#       2
# ----> 3 df_array = np.array(df_mmean['device_count'])
#       4 grad = np.gradient(df_array)
#       5 second_grad = np.gradient(grad)
#
# NameError: name 'df_mmean' is not defined

# %% [markdown]
# # Series Decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
offset = 0
series = df["device_count"][offset:]
dec_m = seasonal_decompose(series, model='multiplicative')
dec_a = seasonal_decompose(series, model='additive')

dec_m.plot()
# dec_a.plot()

# %%
### from statsmodels.tsa.seasonal import seasonal_decompose
import calendar

up = 7
seasonal_m = dec_m.seasonal
seasonal_a = dec_a.seasonal
q = seasonal_m.quantile(0.99)
print(q)
i = 0
days = []
workdays = list(calendar.day_abbr)

clipped = seasonal_m[offset:offset + up].clip(lower=q)
print (clipped)


# Because the change is insignificant, we lose that in the conversion that happens
# in the 
for day in seasonal_m[offset:offset + up]:
    if day > q:
        day_int = df.index.date[offset+i].weekday()
        print(workdays[day_int])
        days.append(workdays[day_int])
        i = i + 1

days = np.asarray(days)
(unique, counts) = np.unique(days, return_counts=True)
frequencies = np.asarray((unique, counts)).T
print(frequencies)
# Out:
# 1.020033750682145
# date
# 2018-10-26    1.020034
# 2018-10-27    1.020034
# 2018-10-28    1.020034
# 2018-10-29    1.020034
# 2018-10-30    1.020034
# 2018-10-31    1.020034
# 2018-11-01    1.020034
# Name: seasonal, dtype: float64
# []

# %%
# print 1 month of seasonality

plt.plot(df.index.date[offset:offset + up], seasonal_m[offset:offset + up])
plt.xticks(rotation = 'vertical')
i = 0
for day in seasonal_m[offset:offset + up]:
        day_int = df.index.date[offset+i].weekday()
        print( str(df.index.date[offset+i]) + " : " +  str(workdays[day_int]))
        i = i + 1
# Out:
# 2015-07-14 : Tue
# 2015-07-15 : Wed
# 2015-07-16 : Thu
# 2015-07-17 : Fri
# 2015-07-18 : Sat
# 2015-07-19 : Sun
# 2015-07-20 : Mon

# %%
plt.plot(df.index.date[0:15], seasonal_a[0:15])
print(df.index.date[0].weekday()) # monday = 0, Sunday = 6
# Out:
# 1

# %%
trend_m = dec_m.trend
trend_a = dec_a.trend
plt.plot(trend_m)
# plt.plot(trend_a)

# %% [markdown]
# # Takes
#
# What we see from the prior decomposition is that the number of online devices per day, has a very strong trend that resembles the hokey stick, something that is very positive for the business. This means that the number of online devices is starting to rise exponentially, which means that the business is picking up and customer are increasing, while also the existing customer possibly activate more and more devices.

# %%
from fbprophet import Prophet
from fbprophet.diagnostics import cross_validation, performance_metrics


# limit = 1357
upper_bound = 1200
lower_bound = 0
forecast_horizon = 150

train_sample = pd.DataFrame({'y': df['device_count'][lower_bound:upper_bound], 'ds': df.index[lower_bound:upper_bound] })
train_sample = train_sample.reset_index()
del train_sample['date']
train_sample.head()

test_sample = df['device_count'][upper_bound:]

p = Prophet(weekly_seasonality=False, changepoint_prior_scale=0.1)
p.add_seasonality(name='weekly', period=30, fourier_order=15, mode = 'multiplicative')

p.fit(train_sample)
future = p.make_future_dataframe(forecast_horizon, freq='D')

forecast = p.predict(future)
fig = p.plot_components(forecast)
fig1 = p.plot(forecast)


print(forecast['yhat'])
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# 0          83.629399
# 1          82.020399
# 2          80.168986
# 3          75.525224
# 4          73.151364
#             ...
# 1345    18993.097869
# 1346    19199.925960
# 1347    19171.634118
# 1348    19286.314309
# 1349    19241.947422
# Name: yhat, Length: 1350, dtype: float64

# %%
import numpy as np

def smape(A, F):
    return 100/len(A) * np.sum(2 * np.abs(F - A) / (np.abs(A) + np.abs(F)))

yhat = forecast['yhat'][upper_bound:1357]
yhat = np.asarray(yhat)
test_sample = np.asarray(test_sample)
print(test_sample)

smape = smape(test_sample[:-7], yhat)
print("Smape is: ", smape)
# Out:
# [14916 14159 13859 15147 15434 15514 15487 15486 14683 14222 15395 15519
#  15655 15715 16095 15085 14673 15913 16157 16342 16041 16173 15402 15052
#  16147 16323 16240 16003 15912 15473 15307 16489 16622 16796 16903 17035
#  15890 15514 16797 17041 17014 17226 17030 16124 16020 17341 17288 17608
#  17421 17625 16759 16459 17719 17763 17703 17712 17453 16727 16620 16511
#  16140 16808 17096 17111 16742 16648 16745 16354 17419 17530 17607 17066
#  16850 18016 17919 18219 18417 18316 17590 17352 18514 18682 18818 18830
#  18877 18073 17776 18973 19255 19545 19752 19357 18461 18125 19476 19569
#  19763 19868 19982 18845 18481 19488 19670 20191 20203 20681 19606 19320
#  20550 20410 20445 20620 20472 19710 19331 20336 20754 21076 20972 21110
#  19931 19640 20964 20878 20882 21002 20884 20098 19755 21020 21269 21303
#  21780 21709 20537 20151 21501 21666 21736 21823 21780 21148 20680 22034
#  22218 22063 22064 22405 21248 20832 22107 22596 22525 22481 22376 21342
#  21026]
# Smape is:  7.199003388013854

# %%
df_cv = cross_validation(p, horizon = '100 days', initial = '600 days', period = '100 days')
df_cv.head()

# %%
df_p = performance_metrics(df_cv)
print("Performance Metric of the FBprophet library according the parameters above\n")
print(df_p)
print("For a horizon of 100 days, we have SMAPE = ", np.square(df_p['mape'][0]))
# Out:
# Performance Metric of the FBprophet library according the parameters above
#
#     horizon           mse         rmse          mae      mape     mdape  \
# 0   10 days  4.019835e+05   634.021699   501.238257  0.037233  0.034617
# 1   11 days  4.444646e+05   666.681757   541.324691  0.039968  0.037961
# 2   12 days  4.864153e+05   697.434790   573.866784  0.042702  0.039664
# 3   13 days  4.625443e+05   680.106069   550.125983  0.040919  0.037961
# 4   14 days  4.251181e+05   652.010793   514.885072  0.038219  0.034389
# ..      ...           ...          ...          ...       ...       ...
# 86  96 days  1.489679e+06  1220.524048  1076.877595  0.069788  0.061330
# 87  97 days  1.483722e+06  1218.081371  1087.658748  0.069354  0.062313
# 88  98 days  1.465175e+06  1210.443931  1094.972885  0.069108  0.068333
# 89  99 days  1.503911e+06  1226.340656  1129.106941  0.071040  0.070289
# 90 100 days  1.588758e+06  1260.459492  1148.091186  0.072654  0.072263
#
#     coverage
# 0   0.100000
# 1   0.066667
# 2   0.066667
# 3   0.100000
# 4   0.133333
# ..       ...
# 86  0.233333
# 87  0.200000
# 88  0.166667
# 89  0.133333
# 90  0.166667
#
# [91 rows x 7 columns]
# For a horizon of 100 days, we have SMAPE =  0.0013862698349513957

# %% [markdown]
# ## From the fbprophet website
#
# > Prophet includes functionality for time series cross validation to measure forecast error using historical data. This is done by selecting cutoff points in the history, and for each of them fitting the model using data only up to that cutoff point. We can then compare the forecasted values to the actual values. This figure illustrates a simulated historical forecast on the Peyton Manning dataset, where the model was fit to a initial history of 5 years, and a forecast was made on a one year horizon.
#
#
#
# ![](https://facebook.github.io/prophet/static/diagnostics_files/diagnostics_3_0.png)

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import pandas as pd
limit = 1357
upper_bound = 1000
lower_bound = 0
forecast_horizon = 300


train_sample = pd.DataFrame({'y': df['device_count'][lower_bound:upper_bound], 'ds':df.index[lower_bound:upper_bound] })
train_sample = train_sample.reset_index()
del train_sample['date']

test_sample = pd.DataFrame({'y': df['device_count'][upper_bound-1:upper_bound + forecast_horizon], 'ds':df.index[upper_bound-1:upper_bound + forecast_horizon] })
test_sample = test_sample.reset_index()
del test_sample['date']

sample_array = np.asarray(train_sample['y'])
test_array = np.asarray(test_sample['y'])

model = ExponentialSmoothing(sample_array, trend='mul', seasonal='mul', seasonal_periods=7)
model_fit = model.fit(use_brute=True)
yhat = model_fit.predict(start = upper_bound, end = upper_bound + forecast_horizon)

f = model_fit.forecast(forecast_horizon)
plt.plot(future_range[:forecast_horizon], f)

future_range = pd.date_range(start = df.index[upper_bound], end = '2021-01', freq  = 'D')
print(future_range)



plt.plot(df.index[:upper_bound + forecast_horizon], df['device_count'][0:upper_bound + forecast_horizon])
plt.plot(future_range[:forecast_horizon+1], yhat)
# Out:
# DatetimeIndex(['2018-04-09', '2018-04-10', '2018-04-11', '2018-04-12',
#                '2018-04-13', '2018-04-14', '2018-04-15', '2018-04-16',
#                '2018-04-17', '2018-04-18',
#                ...
#                '2020-12-23', '2020-12-24', '2020-12-25', '2020-12-26',
#                '2020-12-27', '2020-12-28', '2020-12-29', '2020-12-30',
#                '2020-12-31', '2021-01-01'],
#               dtype='datetime64[ns]', length=999, freq='D')

# %%
# Forecasting Errors

import numpy as np

def smape(A, F):
    return 100/len(A) * np.sum(2 * np.abs(F - A) / (np.abs(A) + np.abs(F)))

smape_error = smape(test_array, yhat)
print(smape_error)

log_error = log_err(test_array, yhat)
plt.plot(log_error, label = "Log Error At/Ft")
plt.legend()

print( "Mean log error: ", np.mean(log_error))
# Out:
# 7.098905748164112
# Mean log error:  0.0662077367734713

# %%
# out of sample = 57 last values

error = np.mean(200 * np.abs(yhat-test_array) / (np.abs(yhat) + np.abs(test_array))).item()
errors = test_array-yhat
errors = pd.DataFrame(errors)
print(errors.describe())
print(" ")
print(error)
print (model_fit.summary())
# Out:
#                  0
# count   101.000000
# mean  -1569.989004
# std    1249.261037
# min   -4277.560457
# 25%   -2753.102301
# 50%   -1355.892432
# 75%    -483.028233
# max     786.181430
#
# 8.729415797473797
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:                    endog   No. Observations:                 1200
# Model:             ExponentialSmoothing   SSE                       19895011.871
# Optimized:                         True   AIC                          11681.083
# Trend:                   Multiplicative   BIC                          11737.074
# Seasonal:                Multiplicative   AICC                         11681.390
# Seasonal Periods:                     7   Date:                 Sun, 05 Apr 2020
# Box-Cox:                          False   Time:                         00:23:17
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.2631579                alpha                 True
# smoothing_slope               0.0526316                 beta                 True
# smoothing_seasonal            0.0526316                gamma                 True
# initial_level                 3102.7384                  l.0                 True
# initial_slope                 1.0153883                  b.0                 True
# initial_seasons.0             0.0170817                  s.0                 True
# initial_seasons.1             0.0170817                  s.1                 True
# initial_seasons.2             0.0180486                  s.2                 True
# initial_seasons.3             0.0183709                  s.3                 True
# initial_seasons.4             0.0183709                  s.4                 True
# initial_seasons.5             0.0170817                  s.5                 True
# initial_seasons.6             0.0196601                  s.6                 True
# ---------------------------------------------------------------------------------

# %%
# compute error for holt-winters

from statsmodels.tsa.holtwinters import SimpleExpSmoothing, Holt, HoltWintersResults
import pandas as pd
from statsmodels.tsa.seasonal import seasonal_decompose


dec_m = seasonal_decompose(series, model='multiplicative')
si = dec_m.seasonal
tr = dec_m.trend

limit = 1356
upper_bound = 1000
lower_bound = 0
forecast_horizon = 300


train_sample = pd.DataFrame({'y': tr[lower_bound:upper_bound], 'ds':df.index[lower_bound:upper_bound] })
train_sample = train_sample.reset_index()
del train_sample['date']
if lower_bound == 0:
    train_sample['y'][lower_bound + 0:lower_bound + 3] = series[lower_bound + 0:lower_bound + 3]/si[lower_bound + 0:lower_bound + 3]
    train_sample['y'][upper_bound - lower_bound - 2:upper_bound - lower_bound] = series[upper_bound - lower_bound - 2:upper_bound - lower_bound]/si[upper_bound - lower_bound - 2:upper_bound - lower_bound]

print(train_sample)

test_sample = pd.DataFrame({'y': df['device_count'][upper_bound:upper_bound + forecast_horizon ], 'ds':df.index[upper_bound:upper_bound + forecast_horizon ] })
test_sample = test_sample.reset_index()
del test_sample['date']

sample_array = np.asarray(train_sample['y']) 

test_array = np.asarray(test_sample['y']) / np.asarray(si[upper_bound:upper_bound + forecast_horizon ])

# print(sample_array)

model2 = Holt(sample_array, exponential = True)
model_fit2 = model2.fit(smoothing_level =0.7)

print("seasonal_component size: ", seasonal_component.size)

# yhat = model_fit2.predict(start = 1000,  end =  1400)*seasonal_component[0:401]
yhat = model_fit2.forecast(forecast_horizon)
offset = 5
yhat = yhat * si[upper_bound: upper_bound + forecast_horizon]




# print(model_fit2.summary())


future_range = pd.date_range(start = df.index[0], end = '2021-01-01', freq  = 'D')

print("Weekday:", future_range[upper_bound].weekday()) 

# monday = 0, sunday = 6

print("Seasonal Weekday:", si.index[0 + offset].weekday())

print(yhat[0])

# print(future_range)

# plt.plot(df.index[:], df['device_count'][:])
plt.plot(future_range[upper_bound:upper_bound + forecast_horizon], yhat, label = "Forecasted values")
plt.plot(df.index[0 + lower_bound:upper_bound + forecast_horizon], df['device_count'][0 + lower_bound:upper_bound + forecast_horizon] , label = "Sample values")
plt.plot(df.index[upper_bound:upper_bound + forecast_horizon], test_array, label = "Out-sample values for testing")
plt.legend()
# sample_array.size
# yhat.size
# Out:
#                y         ds
# 0      52.255467 2015-07-14
# 1      52.149286 2015-07-15
# 2      54.743323 2015-07-16
# 3      55.714286 2015-07-17
# 4      56.857143 2015-07-18
# ..           ...        ...
# 995  6621.285714 2018-04-04
# 996  6651.571429 2018-04-05
# 997  6691.142857 2018-04-06
# 998  6781.724508 2018-04-07
# 999  6748.508621 2018-04-08
#
# [1000 rows x 2 columns]
# seasonal_component size:  406
# Weekday: 0
# Seasonal Weekday: 6
# 6807.148907245522
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Export the Holt data to measure prediction intervals

df_to_export1 = pd.DataFrame({
    "yhat": yhat,
    "test_array": test_array}
)
df_to_export2 = pd.DataFrame({
    "sample_array": sample_array
})

df_to_export1.to_csv(r'test_array.csv')
df_to_export2.to_csv(r'sample_array.csv')

# %%
# Forecasting Errors, out_of_sample

import numpy as np

def smape(A, F):
    return 100/len(A) * np.sum(2 * np.abs(F - A) / (np.abs(A) + np.abs(F)))

smape_error = smape(test_array, yhat)
print("SMAPE error:", smape_error)

def log_err(A, F):
    return (np.log(A/F))

log_error = log_err(test_array, yhat)
plt.plot(log_error, label = "Log Error At/Ft")
plt.legend()

print( "Mean log error: ", np.mean(log_error), "\n")
# Out:
# SMAPE error: 3.8826739729340485
# Mean log error:  0.003159834239448266

# %%
from statsmodels.tsa.holtwinters import HoltWintersResults

# model2 = Holt()
# model2_fit = model2.fit()

model_fit2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               Holt Model Results
# ==============================================================================
# Dep. Variable:                  endog   No. Observations:                 1200
# Model:                           Holt   SSE                        2611644.150
# Optimized:                       True   AIC                           9230.496
# Trend:                       Additive   BIC                           9250.857
# Seasonal:                        None   AICC                          9230.567
# Seasonal Periods:                None   Date:                 Sun, 05 Apr 2020
# Box-Cox:                        False   Time:                         20:28:43
# Box-Cox Coeff.:                  None
# ==============================================================================
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.3000000                alpha                False
# smoothing_slope            0.0319430                 beta                 True
# initial_level              52.269757                  l.0                 True
# initial_slope              0.4343337                  b.0                 True
# ------------------------------------------------------------------------------
# """

# %%
from scipy import stats

def get_prediction_interval(prediction,test_predictions):
    '''
     We assume that the errors are normally distributed.
    '''
    '''
        50	0.67
        55	0.76
        60	0.84
        65	0.93
        70	1.04
        75	1.15
        80	1.28
        85	1.44
        90	1.64
        95	1.96
        96	2.05
        97	2.17
        98	2.33
        99	2.58
    '''
    c = 1.28
    #get standard deviation of y_test
    std = np.std(test_predictions)
    lower = prediction - c * std
    upper = prediction + c * std
    return lower, prediction, upper
# get_prediction_interval(predictions[0], y_test, predictions)

upper_array = []
lower_array = []
success = 0
for y in yhat:
    lower, y, upper = get_prediction_interval(y, yhat)
    upper_array.append(upper)
    lower_array.append(lower)
    # print(lower, y, upper)
    if  (y > lower) and (y < upper):
        success = success + 1
        
upper_array = np.array(upper_array)
lower_array = np.array(lower_array)
success = success / forecast_horizon
print("The predicted y was inside the PI for: ", success*100, "%", " of the times")

plt.plot(future_range[upper_bound:upper_bound + forecast_horizon], yhat)
plt.plot(df.index[0 + lower_bound:upper_bound], sample_array[0 + lower_bound:upper_bound] *si[0 + lower_bound:upper_bound])
plt.plot(future_range[upper_bound:upper_bound + forecast_horizon], upper_array)
plt.plot(future_range[upper_bound:upper_bound + forecast_horizon], lower_array)
# Out:
# The predicted y was inside the PI for:  100.0 %  of the times

# %%
vpd.__version__
# Out:
# '1.0.1'

# %% [markdown]
# # Machine Learning

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.neural_network import MLPRegressor

forecast_horizon = 300
insample = df.iloc[:-forecast_horizon, :]
print(insample)
x_train = np.asarray(insample.index)
x_train = x_train.reshape(-1,1)

y_train = np.asarray(insample['device_count'])
y_train = y_train.reshape(-1,1)

print(x_train)
print(y_train)
outsample = df.iloc[:-forecast_horizon:, :]
x_test = np.asarray(outsample.index)
x_test = x_test.reshape(-1,1)

y_test = np.asarray(outsample['device_count'])
y_test = y_test.reshape(-1,1)

scaler_input = MinMaxScaler(feature_range=(0,1))
scaler_output = MinMaxScaler(feature_range=(0,1))

x_train = scaler_input.fit_transform(x_train)
x_test = scaler_input.transform(x_test)

y_train = scaler_output.fit_transform(np.reshape(y_train, (-1,1)))
for i in range(10):
    mlp = MLPRegressor(hidden_layer_sizes = (100,100), activation = 'relu', early_stopping=True, warm_start=True)
    mlp.fit(x_train, y_train)
    y_hat_mlp = mlp.predict(x_test)
    y_hat_mlp = scaler_output.inverse_transform(np.reshape(y_hat_mlp, (-1,1)))
print(np.mean(200 * np.abs(y_hat_mlp - y_test)/ (np.abs(y_hat_mlp) + np.abs(y_test))).item() )

# We run the model several tiems and set the warm_start=True so that with each iteration
# them model gets better. This is done to increase accuracy.
# The experiment is proven to be correct as we manage to bring SMAPE down to 9.95, relatively close to the
# exponential smoothing that we run before.
plt.plot(y_test)
plt.plot(y_hat_mlp)
# Out:
#             device_count
# date
# 2015-07-14            53
# 2015-07-15            53
# 2015-07-16            56
# 2015-07-17            57
# 2015-07-18            57
# ...                  ...
# 2018-05-31          8820
# 2018-06-01          8674
# 2018-06-02          8325
# 2018-06-03          8189
# 2018-06-04          8745
#
# [1057 rows x 1 columns]
# [['2015-07-14T00:00:00.000000000']
#  ['2015-07-15T00:00:00.000000000']
#  ['2015-07-16T00:00:00.000000000']
#  ...
#  ['2018-06-02T00:00:00.000000000']
#  ['2018-06-03T00:00:00.000000000']
#  ['2018-06-04T00:00:00.000000000']]
# [[  53]
#  [  53]
#  [  56]
#  ...
#  [8325]
#  [8189]
#  [8745]]
# /usr/local/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:1342: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 17.054722755802185

# %%
# Forecasting Errors

import numpy as np

def smape(A, F):
    return 100/len(A) * np.sum(2 * np.abs(F - A) / (np.abs(A) + np.abs(F)))

smape_error = smape(y_test, y_hat_mlp)
print(smape_error)

log_error = log_err(test_array, yhat)
plt.plot(log_error, label = "Log Error At/Ft")
plt.legend()

print( "Mean log error: ", np.mean(log_error))
# Out:
# 17.054722755802185
# Mean log error:  0.0662077367734713
